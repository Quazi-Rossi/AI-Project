# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DCL\Downloads\Final4.csv')

# %%
df.head(70)
# Out:
#                             Time                   CGPA  \
# 0    2019/08/06 2:38:34 AM GMT+6                      4
# 1    2019/08/06 2:47:23 AM GMT+6  between 3.00 and 3.50
# 2    2019/08/06 2:49:35 AM GMT+6  between 2.50 and 3.00
# 3    2019/08/06 2:53:06 AM GMT+6  Between 2.00 and 2.50
# 4    2019/08/06 2:54:14 AM GMT+6  between 3.00 and 3.50
# 5    2019/08/06 3:01:16 AM GMT+6  between 3.00 and 3.50
# 6    2019/08/06 3:05:12 AM GMT+6  between 3.00 and 3.50
# 7    2019/08/06 3:06:30 AM GMT+6  between 3.00 and 3.50
# 8    2019/08/06 4:09:40 AM GMT+6  between 3.50 and 3.80
# 9    2019/08/06 4:34:09 AM GMT+6  between 2.50 and 3.00
# 10   2019/08/06 7:39:14 AM GMT+6  between 3.00 and 3.50
# 11   2019/08/06 8:27:21 AM GMT+6  between 3.00 and 3.50
# 12   2019/08/06 8:33:42 AM GMT+6  between 3.00 and 3.50
# 13   2019/08/06 8:34:00 AM GMT+6  between 3.50 and 3.80
# 14   2019/08/06 9:18:46 AM GMT+6  between 3.00 and 3.50
# 15   2019/08/06 9:44:29 AM GMT+6  between 3.50 and 3.80
# ...

# %%
x = df.drop(['Time','permanent','Ship'],axis=1)

# %%
y = x['CGPA']

# %%
x = x.drop(['CGPA'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(['CGPA'])
# Out:
# LabelEncoder()

# %%
CGPA= le.transform(['CGPA'])

# %%
le.fit(x['Hometown'])
# Out:
# LabelEncoder()

# %%
x['Hometown'] = le.transform(x['Hometown'])

# %%
le.fit(x['School'])
# Out:
# LabelEncoder()

# %%
x['School'] = le.transform(x['School'])

# %%
le.fit(x['College'])
# Out:
# LabelEncoder()

# %%
x['College'] = le.transform(x['College'])

# %%
le.fit(x['English'])
# Out:
# LabelEncoder()

# %%
x['English'] = le.transform(x['English'])

# %%
le.fit(x['Knowledge'])
# Out:
# LabelEncoder()

# %%
x['Knowledge'] = le.transform(x['Knowledge'])

# %%
le.fit(x['Reading'])
# Out:
# LabelEncoder()

# %%
x['Reading'] = le.transform(x['Reading'])

# %%
le.fit(x['Codeing'])
# Out:
# LabelEncoder()

# %%
x['Codeing'] = le.transform(x['Codeing'])

# %%
le.fit(x['Part'])
# Out:
# LabelEncoder()

# %%
x['Part'] = le.transform(x['Part'])

# %%
le.fit(x['Married'])
# Out:
# LabelEncoder()

# %%
x['Married'] = le.transform(x['Married'])

# %%
le.fit(x['P.A'])
# Out:
# LabelEncoder()

# %%
x['P.A'] = le.transform(x['P.A'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
x, y, test_size=0.2, random_state=174)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial')

# %%
clf.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.4375
